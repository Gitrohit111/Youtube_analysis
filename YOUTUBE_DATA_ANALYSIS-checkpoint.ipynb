# %% [markdown]
# # YOUTUBE_DATA_ANALYSIS

# %% [markdown]
# # Importing Libarires

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Global YouTube Statistics.csv', encoding= 'unicode_escape')

# %% [markdown]
# # (EDA) Exploratory Data Analysis And Data Cleaning

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df.tail()
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 990   991             Natan por Aï¿     12300000  9.029610e+09
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 992   993                     Panda     12300000  2.214684e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category                     Title  uploads         Country  \
# 990          Sports             Natan por Aï¿     1200          Brazil
# 991  People & Blogs  Free Fire India Official     1500           India
# 992             NaN               HybridPanda     2452  United Kingdom
# 993          Gaming               RobTopGames       39          Sweden
# 994          Comedy              Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 990           BR  Entertainment  ...                      700000.0
# ...

# %%
df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
df.describe(include='all')
# Out:
#              rank  Youtuber   subscribers   video views       category  \
# count   995.00000       995  9.950000e+02  9.950000e+02            949
# unique        NaN       995           NaN           NaN             18
# top           NaN  T-Series           NaN           NaN  Entertainment
# freq          NaN         1           NaN           NaN            241
# mean    498.00000       NaN  2.298241e+07  1.103954e+10            NaN
# std     287.37606       NaN  1.752611e+07  1.411084e+10            NaN
# min       1.00000       NaN  1.230000e+07  0.000000e+00            NaN
# 25%     249.50000       NaN  1.450000e+07  4.288145e+09            NaN
# 50%     498.00000       NaN  1.770000e+07  7.760820e+09            NaN
# 75%     746.50000       NaN  2.460000e+07  1.355470e+10            NaN
# max     995.00000       NaN  2.450000e+08  2.280000e+11            NaN
#
#           Title        uploads        Country Abbreviation   channel_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df.shape
# Out:
# (995, 28)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [rank, Youtuber, subscribers, video views, category, Title, uploads, Country, Abbreviation, channel_type, video_views_rank, country_rank, channel_type_rank, video_views_for_the_last_30_days, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, subscribers_for_last_30_days, created_year, created_month, created_date, Gross tertiary education enrollment (%), Population, Unemployment rate, Urban_population, Latitude, Longitude]
# Index: []
#
# [0 rows x 28 columns]

# %%
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
# showing null values with the help of Heatmap.

sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.dropna()
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# 8       9                 Like Nastya    106000000  9.047906e+10
# ..    ...                         ...          ...           ...
# 989   990                   Migos ATL     12400000  6.993406e+09
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# ...

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
# Removing the extra data. 
df.drop(columns=['Title','Abbreviation','created_date','Unemployment rate','Longitude','Unemployment rate'],axis=1,inplace=True)

# %%
df.drop(['channel_type'],axis=1,inplace=True)

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category  uploads         Country  video_views_rank  \
# 0               Music    20082           India               1.0
# ...

# %%
df[['channel_type_rank']]
# Out:
#      channel_type_rank
# 0                  1.0
# 1               7423.0
# 2                  1.0
# 3                  1.0
# 4                  2.0
# ..                 ...
# 990              172.0
# 991               69.0
# 992             1202.0
# 993               69.0
# 994               44.0
#
# [995 rows x 1 columns]

# %%
df.Youtuber.head(10)
# Out:
# 0                      T-Series
# 1                YouTube Movies
# 2                       MrBeast
# 3    Cocomelon - Nursery Rhymes
# 4                     SET India
# 5                         Music
# 6           ýýý Kids Diana Show
# 7                     PewDiePie
# 8                   Like Nastya
# 9                 Vlad and Niki
# Name: Youtuber, dtype: object

# %%
df.Youtuber.value_counts().head(10)
# Out:
# T-Series                    1
# Hongyu ASMR ï¿½ï¿½          1
# Sony LIV                    1
# T-Series Hamaar Bhojpuri    1
# Oyuncak Avï¿                1
# CNN                         1
# NDTV India                  1
# It's Mamix                  1
# Kim Loaiza                  1
# Daftar Populer              1
# Name: Youtuber, dtype: int64

# %%
df.Youtuber.sort_values().head(10)
# Out:
# 783            #Refugio Mental
# 939           #Refï¿½ï¿½ï¿½ï¿½
# 817            123 GO! Spanish
# 217      1MILLION Dance Studio
# 250       1theK (ï¿½ï¿½ï¿½ï¿½ï
# 16             5-Minute Crafts
# 365        5-Minute Crafts DIY
# 627     5-Minute Crafts FAMILY
# 397       5-Minute Crafts PLAY
# 713    5-Minute Crafts Recycle
# Name: Youtuber, dtype: object

# %%
df[(df['Country']=='India') & (df['highest_monthly_earnings']=='1000000')]
# Out:
# Empty DataFrame
# Columns: [rank, Youtuber, subscribers, video views, category, uploads, Country, video_views_rank, country_rank, channel_type_rank, video_views_for_the_last_30_days, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, subscribers_for_last_30_days, created_year, created_month, Gross tertiary education enrollment (%), Population, Urban_population, Latitude]
# Index: []
#
# [0 rows x 22 columns]

# %%
youtuber= df.groupby('Youtuber').size().reset_index(name='Counts').sort_values('Counts',
                                                                            ascending=False,
                                                                           ignore_index=True)

# %%
youtuber
# Out:
#                    Youtuber  Counts
# 0           #Refugio Mental       1
# 1            SAAIHALILINTAR       1
# 2               RobTopGames       1
# 3          Robin Hood Gamer       1
# 4               RobleisIUTU       1
# ..                      ...     ...
# 990              Heroindori       1
# 991                   HiMan       1
# 992          HolaSoyGerman.       1
# 993      Hongyu ASMR ï¿½ï¿½       1
# 994  ýýýýýýýýýýýýýýýýýýýýýý       1
#
# [995 rows x 2 columns]

# %%
plt.figure(figsize=(10,5))
sns.barplot(x = youtuber.Counts.head(15), y = youtuber.Youtuber.head(15),data=youtuber.head(15))
# Out:
# <AxesSubplot:xlabel='Counts', ylabel='Youtuber'>

# %%
plt.figure(figsize=(15,8))
sns.countplot(df.category.head(10))
plt.xlabel('Category')
plt.ylabel('number of category')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(20,10))
sns.histplot(x=df.Youtuber.head(10),data=df,kde = True,hue=df.Country.head(10),color='red')
# Out:
# <AxesSubplot:xlabel='Youtuber', ylabel='Count'>

# %%
sns.displot(x = df.highest_monthly_earnings.head(10),hue = df.Country.head(10),kind='kde',fill=True)

# %%
plt.figure(figsize=(18,10))
sns.countplot(df.category.head(50))
# Out:
# <AxesSubplot:xlabel='category', ylabel='count'>

# %%
plt.figure(figsize=(18,10))
sns.countplot(df.category)
# Out:
# <AxesSubplot:xlabel='category', ylabel='count'>

# %%
# Distribution plot with youtuber column
plt.figure(figsize=(15,10))
sns.histplot(data=df, x=df.Youtuber.head(10), y=df.created_year.head(10),kde=True)
# Out:
# <AxesSubplot:xlabel='Youtuber', ylabel='created_year'>

# %%
plt.figure(figsize=(15,10))
sns.histplot(data=df, x=df.Youtuber.head(10), y=df.created_month.head(10),kde=True)
# Out:
# <AxesSubplot:xlabel='Youtuber', ylabel='created_month'>

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category  uploads         Country  video_views_rank  \
# 0               Music    20082           India               1.0
# ...

# %%
df1 = df.Latitude.round(2)

# %%
df1
# Out:
# 0      20.59
# 1      37.09
# 2      37.09
# 3      37.09
# 4      20.59
#        ...
# 990   -14.24
# 991    20.59
# 992    55.38
# 993    60.13
# 994    20.59
# Name: Latitude, Length: 995, dtype: float64

# %%
sns.displot(x = df.highest_monthly_earnings.head(10),hue = df.Youtuber.head(10),kind='kde',fill=True)

# %%
sns.histplot(df.subscribers.head(50),kde=True)
# Out:
# <AxesSubplot:xlabel='subscribers', ylabel='Count'>

# %% [markdown]
# # END
